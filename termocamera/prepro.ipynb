# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
#apen and read an image jpg to numpy
bianco = cv2.imread('bianco.jpg')
verde = cv2.imread('verde.jpg')

# %%
plt.imshow(bianco)

# %%
plt.imshow(verde)

# %%
print(bianco[50][50])
print(verde[0][0])
# Out:
# [135 135 135]
# [110 254 128]

# %%
# (pixelbianco/pixelverde):x = 255:550
x = bianco[50][50][0]
y = verde[50][50][1]

type(x)
# Out:
# numpy.uint8

# %%
# 150:255= x:pixelBianco
x = y / 64

# %%
print(x)
# Out:
# 3.5

# %%
noRGB= np.load('frame.npy')

# %%
noRGB.shape
# Out:
# (1, 196608)

# %%
image_array = np.reshape(noRGB, (2,192, 256,2))

# Ora puoi accedere alle due immagini separatamente
image1 = image_array[0]
image2 = image_array[1]

# %%
primo = image_array[0,:,:,0]
secondo = image_array[0,:,:,1]
terzo = image_array[1,:,:,0]    
quarto = image_array[1,:,:,1]

# %%
plt.imshow(primo)

# %%
plt.imshow(terzo)

# %%
plt.imshow(quarto)

# %%
hi = primo[175][100]
lo = quarto[175][100]
to = terzo[175][100]
#print(hi,lo)
lo = lo*256
rawtemp = lo+hi+to
#print(rawtemp)
temp = (rawtemp/64)-273.15
temp = round(temp,2)
print(temp)
# Out:
# -121.7

# %%
lo/256
# Out:
# 73.0

# %%
pixel = image2[175][100]
pixel
hi = pixel[0]
lo = pixel[1]
#print(hi,lo)
lo = lo*256
rawtemp = lo+hi
#print(rawtemp)
temp = (rawtemp/64)-273.15
temp = round(temp,2)
print(temp)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 3
#       1 pixel = terzo[175][100]
#       2 pixel
# ----> 3 hi = pixel[0]
#       4 lo = pixel[1]
#       5 #print(hi,lo)
#
# IndexError: invalid index to scalar variable.
